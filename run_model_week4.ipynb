# %%
from flaskexample.perfume_recommendation import Fragrance_Retrieve_Model
gre = Fragrance_Retrieve_Model()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/biqiongyu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/biqiongyu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
love_message = "I'm looking for a Christmas gift for my boyfriend. He loves sea."
hate_message = "vanilla, sage"

rec = gre.query_similar_perfumes(love_message, hate_message)
rec
# Out:
#                          semantic_similarity  lsi_similarity  tot_similarity
# name
# Acqua Di Gio Pour Homme             0.124755        0.505297        0.391135
# Invictus                            0.088375        0.506432        0.381015
# Versace Man Eau Fraiche             0.053744        0.489973        0.359104
# The One For Men                     0.146158        0.447474        0.357079
# Pour Homme                          0.122082        0.454628        0.354864
# L'Homme                             0.085526        0.435835        0.330742
# ’REPLICA’ Sailing Day               0.028696        0.448204        0.322352
# Light Blue Pour Homme               0.079409        0.425907        0.321957
# Eros                                0.087151        0.388386        0.298015
# Legend                              0.018912        0.405698        0.289662

# %%
love_message = "I love sea"
hate_message = ""

y = gre.get_message_lsi_embedding_vector(love_message)
rec = gre.query_similar_perfumes(love_message, hate_message)
rec
# Out:
#                               semantic_similarity  lsi_similarity  \
# name
# Vanilla Vibes                            0.105865        0.669170
# Wood Sage & Sea Salt Cologne             0.044756        0.509309
# ’REPLICA’ Sailing Day                   -0.083036        0.505758
# Magic Salty Flower                      -0.029266        0.415683
# Wild Bluebell Cologne                    0.038061        0.386381
#
#                               tot_similarity
# name
# Vanilla Vibes                       0.500179
# Wood Sage & Sea Salt Cologne        0.369943
# ’REPLICA’ Sailing Day               0.329120
# Magic Salty Flower                  0.282199
# Wild Bluebell Cologne               0.281885

# %%
# test unrevelant messages
love_message = "iPhone"
hate_message = ""

y = gre.get_message_lsi_embedding_vector(love_message)
rec = gre.query_similar_perfumes(love_message, hate_message)
rec

# %%
hate_message = "sage, vanilla"
gre.get_dissimilarity_scores(hate_message).head(10)
# Out:
#                                                semantic_dissimilarity  \
# name
# Y Eau de Parfum                                             -0.102015
# Man Blue                                                     0.110995
# Y Eau de Toilette                                           -0.137191
# Fucking Fabulous                                             0.105193
# Vanilla Vibes                                               -0.002420
# Vanille Insensée Cologne Absolue Pure Perfume               -0.020127
# Wood Sage & Sea Salt Cologne                                -0.029290
# Wild Bluebell Cologne                                       -0.001715
# Vanille Coco                                                 0.007087
# Vanilla Woods Eau de Parfum                                 -0.026301
#
#                                                lsi_dissimilarity  \
# name
# Y Eau de Parfum                                         0.668792
# Man Blue                                                0.549594
# Y Eau de Toilette                                       0.500753
# Fucking Fabulous                                        0.337039
# Vanilla Vibes                                           0.376167
# Vanille Insensée Cologne Absolue Pure Perfume           0.365216
# Wood Sage & Sea Salt Cologne                            0.363148
# Wild Bluebell Cologne                                   0.342986
# Vanille Coco                                            0.257363
# Vanilla Woods Eau de Parfum                             0.255559
#
#                                                tot_dissimilarity
# name
# Y Eau de Parfum                                         0.437550
# Man Blue                                                0.418015
# Y Eau de Toilette                                       0.309369
# Fucking Fabulous                                        0.267485
# Vanilla Vibes                                           0.262591
# Vanille Insensée Cologne Absolue Pure Perfume           0.249613
# Wood Sage & Sea Salt Cologne                            0.245416
# Wild Bluebell Cologne                                   0.239576
# Vanille Coco                                            0.182280
# Vanilla Woods Eau de Parfum                             0.171001

# %%
love_message = ""
hate_message = "vanilla, sage"
gre.get_dissimilarity_scores(hate_message).head(10)
# Out:
#                                                semantic_dissimilarity  \
# name
# Y Eau de Parfum                                             -0.079210
# Man Blue                                                     0.078007
# Y Eau de Toilette                                            0.108998
# Wood Sage & Sea Salt Cologne                                 0.080396
# Wild Bluebell Cologne                                        0.095412
# Vanilla Vibes                                               -0.022058
# Fucking Fabulous                                             0.004343
# Vanilla Woods Eau de Parfum                                  0.142169
# Vanille Insensée Cologne Absolue Pure Perfume               -0.140870
# Vanille Coco                                                 0.041607
#
#                                                lsi_dissimilarity  \
# name
# Y Eau de Parfum                                         0.668792
# Man Blue                                                0.549594
# Y Eau de Toilette                                       0.500753
# Wood Sage & Sea Salt Cologne                            0.363148
# Wild Bluebell Cologne                                   0.342986
# Vanilla Vibes                                           0.376167
# Fucking Fabulous                                        0.337039
# Vanilla Woods Eau de Parfum                             0.255559
# Vanille Insensée Cologne Absolue Pure Perfume           0.365216
# Vanille Coco                                            0.257363
#
#                                                tot_dissimilarity
# name
# Y Eau de Parfum                                         0.444391
# Man Blue                                                0.408118
# Y Eau de Toilette                                       0.383226
# Wood Sage & Sea Salt Cologne                            0.278322
# Wild Bluebell Cologne                                   0.268714
# Vanilla Vibes                                           0.256699
# Fucking Fabulous                                        0.237231
# Vanilla Woods Eau de Parfum                             0.221542
# Vanille Insensée Cologne Absolue Pure Perfume           0.213390
# Vanille Coco                                            0.192636

# %%
love_message = ""
hate_message = "vanilla"
gre.get_dissimilarity_scores(hate_message).head()
# Out:
#                                                semantic_dissimilarity  \
# name
# Vanille Insensée Cologne Absolue Pure Perfume               -0.080519
# Vanilla Woods Eau de Parfum                                  0.035872
# Vanilla Vibes                                               -0.121573
# Vanille Coco                                                 0.010427
# KAYALI VANILLA | 28                                         -0.049660
#
#                                                lsi_dissimilarity  \
# name
# Vanille Insensée Cologne Absolue Pure Perfume           0.838896
# Vanilla Woods Eau de Parfum                             0.689167
# Vanilla Vibes                                           0.668166
# Vanille Coco                                            0.581234
# KAYALI VANILLA | 28                                     0.508712
#
#                                                tot_dissimilarity
# name
# Vanille Insensée Cologne Absolue Pure Perfume           0.563071
# Vanilla Woods Eau de Parfum                             0.493179
# Vanilla Vibes                                           0.431244
# Vanille Coco                                            0.409992
# KAYALI VANILLA | 28                                     0.341201

# %%
#stability test
love_message = "I like chocolate"
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                    semantic_similarity  lsi_similarity  tot_similarity
# name
# Angel                         0.059908        0.779969        0.563951
# Alien                         0.062192        0.680298        0.494866
# Prada Candy Night             0.087155        0.500014        0.376156

# %%
#stability test
love_message = "I like chocolate and vanilla"
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                                semantic_similarity  \
# name
# Angel                                                    -0.012572
# Vanille Insensée Cologne Absolue Pure Perfume             0.048787
# Alien                                                     0.067096
# Vanilla Woods Eau de Parfum                              -0.086782
# Vanille Coco                                             -0.066251
#
#                                                lsi_similarity  tot_similarity
# name
# Angel                                                0.629206        0.436672
# Vanille Insensée Cologne Absolue Pure Perfume        0.577045        0.418567
# Alien                                                0.538112        0.396807
# Vanilla Woods Eau de Parfum                          0.462539        0.297743
# Vanille Coco                                         0.439746        0.287947

# %%
#stability test
love_message = "I like chocolate vanilla and rose."
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                                semantic_similarity  \
# name
# Stella                                                    0.053001
# Roses De Chloé                                           -0.060719
# Amazing Grace Ballet Rose Eau de Toilette                -0.054555
# Angel                                                     0.079108
# Alien                                                     0.191084
# Vanille Insensée Cologne Absolue Pure Perfume            -0.016989
# Vanilla Woods Eau de Parfum                               0.096090
#
#                                                lsi_similarity  tot_similarity
# name
# Stella                                               0.614613        0.446130
# Roses De Chloé                                       0.616488        0.413326
# Amazing Grace Ballet Rose Eau de Toilette            0.550851        0.369229
# Angel                                                0.447654        0.337090
# Alien                                                0.398334        0.336159
# Vanille Insensée Cologne Absolue Pure Perfume        0.432567        0.297700
# Vanilla Woods Eau de Parfum                          0.364992        0.284322

# %%
#stability test
love_message = "I like chocolate vanilla rose and sage."
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                            semantic_similarity  \
# name
# Y Eau de Parfum                                       0.065709
# Roses De Chloé                                       -0.028660
# Amazing Grace Ballet Rose Eau de Toilette             0.013948
#
#                                            lsi_similarity  tot_similarity
# name
# Y Eau de Parfum                                  0.530271        0.390903
# Roses De Chloé                                   0.428567        0.291399
# Amazing Grace Ballet Rose Eau de Toilette        0.394139        0.280082

# %%
#stability test
love_message = "I like chocolate vanilla sage and rose."
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                            semantic_similarity  \
# name
# Y Eau de Parfum                                      -0.069610
# Stella                                                0.000622
# Y Eau de Toilette                                     0.081441
# Amazing Grace Ballet Rose Eau de Toilette             0.044449
#
#                                            lsi_similarity  tot_similarity
# name
# Y Eau de Parfum                                  0.530271        0.350307
# Stella                                           0.440851        0.308782
# Y Eau de Toilette                                0.388812        0.296601
# Amazing Grace Ballet Rose Eau de Toilette        0.394139        0.289232
