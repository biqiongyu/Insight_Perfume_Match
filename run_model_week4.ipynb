# %%
from flaskexample.perfume_recommendation import Fragrance_Retrieve_Model
gre = Fragrance_Retrieve_Model()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/biqiongyu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/biqiongyu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
love_message = "I'm looking for a Christmas gift for my boyfriend. He loves sea."
hate_message = "vanilla, sage"

rec = gre.query_similar_perfumes(love_message, hate_message)
rec
# Out:
#                          semantic_similarity  lsi_similarity  tot_similarity
# name
# Acqua Di Gio Pour Homme            -0.006165        0.324919        0.225594
# Legend                             -0.012073        0.302311        0.207996
# ’REPLICA’ Sailing Day              -0.045180        0.313521        0.205911
# Light Blue Pour Homme              -0.003322        0.292432        0.203706

# %%
love_message = "I love sea"
hate_message = ""

y = gre.get_message_lsi_embedding_vector(love_message)
rec = gre.query_similar_perfumes(love_message, hate_message)
rec
# Out:
#                               semantic_similarity  lsi_similarity  \
# name
# Vanilla Vibes                            0.016703        0.636951
# Wood Sage & Sea Salt Cologne            -0.054289        0.486382
# ’REPLICA’ Sailing Day                    0.009098        0.332034
# Wild Bluebell Cologne                   -0.037335        0.336206
# Tory Burch Nuit Azur                     0.050695        0.294773
#
#                               tot_similarity
# name
# Vanilla Vibes                       0.450876
# Wood Sage & Sea Salt Cologne        0.324181
# ’REPLICA’ Sailing Day               0.235153
# Wild Bluebell Cologne               0.224144
# Tory Burch Nuit Azur                0.221549

# %%
love_message = "I love sea"
hate_message = "vanilla"

y = gre.get_message_lsi_embedding_vector(love_message)
rec = gre.query_similar_perfumes(love_message, hate_message)
rec
# Out:
#                               semantic_similarity  lsi_similarity  \
# name
# Wood Sage & Sea Salt Cologne            -0.054289        0.486382
# ’REPLICA’ Sailing Day                    0.009098        0.332034
# Wild Bluebell Cologne                   -0.037335        0.336206
# Tory Burch Nuit Azur                     0.050695        0.294773
#
#                               tot_similarity
# name
# Wood Sage & Sea Salt Cologne        0.324181
# ’REPLICA’ Sailing Day               0.235153
# Wild Bluebell Cologne               0.224144
# Tory Burch Nuit Azur                0.221549

# %%
# test unrevelant messages
love_message = "iPhone"
hate_message = ""

y = gre.get_message_lsi_embedding_vector(love_message)
rec = gre.query_similar_perfumes(love_message, hate_message)
rec

# %%
hate_message = "sage, vanilla"
gre.get_dissimilarity_scores(hate_message).head(10)
# Out:
#                                                semantic_dissimilarity  \
# name
# Y Eau de Parfum                                             -0.059009
# Wild Bluebell Cologne                                        0.094355
# Wood Sage & Sea Salt Cologne                                 0.169837
# Man Blue                                                    -0.154808
# Fucking Fabulous                                            -0.143849
# Vanille Insensée Cologne Absolue Pure Perfume                0.068374
# Vanilla Vibes                                                0.005890
# Y Eau de Toilette                                            0.015819
# Orange Blossom Cologne                                       0.107085
# Peony & Blush Suede Cologne                                  0.115333
#
#                                                lsi_dissimilarity  \
# name
# Y Eau de Parfum                                         0.583593
# Wild Bluebell Cologne                                   0.393240
# Wood Sage & Sea Salt Cologne                            0.346156
# Man Blue                                                0.400536
# Fucking Fabulous                                        0.383754
# Vanille Insensée Cologne Absolue Pure Perfume           0.278776
# Vanilla Vibes                                           0.259187
# Y Eau de Toilette                                       0.235251
# Orange Blossom Cologne                                  0.176187
# Peony & Blush Suede Cologne                             0.142294
#
#                                                tot_dissimilarity
# name
# Y Eau de Parfum                                         0.390813
# Wild Bluebell Cologne                                   0.303575
# Wood Sage & Sea Salt Cologne                            0.293260
# Man Blue                                                0.233933
# Fucking Fabulous                                        0.225473
# Vanille Insensée Cologne Absolue Pure Perfume           0.215655
# Vanilla Vibes                                           0.183198
# Y Eau de Toilette                                       0.169421
# Orange Blossom Cologne                                  0.155456
# Peony & Blush Suede Cologne                             0.134206

# %%
love_message = ""
hate_message = "vanilla, sage"
gre.get_dissimilarity_scores(hate_message).head(10)
# Out:
#                                                semantic_dissimilarity  \
# name
# Y Eau de Parfum                                              0.024095
# Man Blue                                                     0.006363
# Wild Bluebell Cologne                                       -0.021655
# Fucking Fabulous                                            -0.038549
# Wood Sage & Sea Salt Cologne                                -0.015539
# Vanille Insensée Cologne Absolue Pure Perfume                0.057736
# Vanilla Vibes                                                0.061571
# Y Eau de Toilette                                           -0.009780
# Vanilla Woods Eau de Parfum                                  0.004426
# Orange Blossom Cologne                                      -0.009776
#
#                                                lsi_dissimilarity  \
# name
# Y Eau de Parfum                                         0.583593
# Man Blue                                                0.400536
# Wild Bluebell Cologne                                   0.393240
# Fucking Fabulous                                        0.383754
# Wood Sage & Sea Salt Cologne                            0.346156
# Vanille Insensée Cologne Absolue Pure Perfume           0.278776
# Vanilla Vibes                                           0.259187
# Y Eau de Toilette                                       0.235251
# Vanilla Woods Eau de Parfum                             0.200987
# Orange Blossom Cologne                                  0.176187
#
#                                                tot_dissimilarity
# name
# Y Eau de Parfum                                         0.415744
# Man Blue                                                0.282284
# Wild Bluebell Cologne                                   0.268772
# Fucking Fabulous                                        0.257063
# Wood Sage & Sea Salt Cologne                            0.237647
# Vanille Insensée Cologne Absolue Pure Perfume           0.212464
# Vanilla Vibes                                           0.199902
# Y Eau de Toilette                                       0.161742
# Vanilla Woods Eau de Parfum                             0.142019
# Orange Blossom Cologne                                  0.120398

# %%
love_message = ""
hate_message = "vanilla"
gre.get_dissimilarity_scores(hate_message).head()
# Out:
#                                                semantic_dissimilarity  \
# name
# Vanille Insensée Cologne Absolue Pure Perfume                0.041975
# Vanilla Woods Eau de Parfum                                 -0.078928
# Vanilla Vibes                                                0.018162
# KAYALI VANILLA | 28                                          0.030251
# Vanille Coco                                                -0.100333
#
#                                                lsi_dissimilarity  \
# name
# Vanille Insensée Cologne Absolue Pure Perfume           0.841920
# Vanilla Woods Eau de Parfum                             0.549822
# Vanilla Vibes                                           0.507664
# KAYALI VANILLA | 28                                     0.502217
# Vanille Coco                                            0.504892
#
#                                                tot_dissimilarity
# name
# Vanille Insensée Cologne Absolue Pure Perfume           0.601936
# Vanilla Woods Eau de Parfum                             0.361197
# Vanilla Vibes                                           0.360813
# KAYALI VANILLA | 28                                     0.360627
# Vanille Coco                                            0.323324

# %%
#stability test
love_message = "I like chocolate"
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#        semantic_similarity  lsi_similarity  tot_similarity
# name
# Angel            -0.053399        0.776192        0.527315

# %%
#stability test
love_message = "I like chocolate and vanilla"
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                                semantic_similarity  \
# name
# Angel                                                    -0.013713
# Vanille Insensée Cologne Absolue Pure Perfume            -0.007802
# Vanille Coco                                              0.051414
# Vanilla Woods Eau de Parfum                               0.032138
#
#                                                lsi_similarity  tot_similarity
# name
# Angel                                                0.695914        0.483026
# Vanille Insensée Cologne Absolue Pure Perfume        0.416488        0.289201
# Vanille Coco                                         0.341718        0.254627
# Vanilla Woods Eau de Parfum                          0.301597        0.220759

# %%
#stability test
love_message = "I like chocolate vanilla and rose."
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                                semantic_similarity  \
# name
# Angel                                                    -0.094752
# Amazing Grace Ballet Rose Eau de Toilette                 0.036073
# Roses De Chloé                                           -0.124447
# Stella                                                    0.151501
# Vanille Insensée Cologne Absolue Pure Perfume            -0.015568
#
#                                                lsi_similarity  tot_similarity
# name
# Angel                                                0.566136        0.367870
# Amazing Grace Ballet Rose Eau de Toilette            0.454229        0.328782
# Roses De Chloé                                       0.514314        0.322686
# Stella                                               0.268668        0.233518
# Vanille Insensée Cologne Absolue Pure Perfume        0.338855        0.232528

# %%
#stability test
love_message = "I like chocolate vanilla rose and sage."
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                            semantic_similarity  \
# name
# Y Eau de Parfum                                       0.104922
# Roses De Chloé                                        0.110628
# Angel                                                -0.045119
# Amazing Grace Ballet Rose Eau de Toilette             0.076007
# Fucking Fabulous                                      0.003569
#
#                                            lsi_similarity  tot_similarity
# name
# Y Eau de Parfum                                  0.445500        0.343327
# Roses De Chloé                                   0.371429        0.293189
# Angel                                            0.407181        0.271491
# Amazing Grace Ballet Rose Eau de Toilette        0.321637        0.247948
# Fucking Fabulous                                 0.292804        0.206033

# %%
#stability test
love_message = "I like chocolate vanilla sage and rose."
hate_message = ""

recs = gre.query_similar_perfumes(love_message, hate_message)
recs
# Out:
#                                            semantic_similarity  \
# name
# Y Eau de Parfum                                      -0.093637
# Angel                                                -0.053893
# Wild Bluebell Cologne                                 0.120533
# Roses De Chloé                                       -0.064927
# Man Blue                                              0.057401
# Amazing Grace Ballet Rose Eau de Toilette            -0.058930
# Wood Sage & Sea Salt Cologne                          0.057528
#
#                                            lsi_similarity  tot_similarity
# name
# Y Eau de Parfum                                  0.445500        0.283759
# Angel                                            0.407181        0.268859
# Wild Bluebell Cologne                            0.302446        0.247872
# Roses De Chloé                                   0.371429        0.240522
# Man Blue                                         0.304558        0.230411
# Amazing Grace Ballet Rose Eau de Toilette        0.321637        0.207467
# Wood Sage & Sea Salt Cologne                     0.262181        0.200785
